# %%
# !export PATH="/opt/conda/lib"

# %%
# !echo $LD_LIBRARY_PATH
# Out:
# /usr/local/nvidia/lib:/usr/local/nvidia/lib64:/opt/conda/lib

# %%
import os
os.environ['LD_LIBRARY_PATH']=os.environ['LD_LIBRARY_PATH']+':/opt/conda/lib'

# %%
#pre-train MW dataset with multi-scale 
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 300 --img 864 864 --multi-scale --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights '' --name pretrain_dataright_e300_bs8_ms_img864_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='pretrain_dataright_e300_bs8_ms_img864_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/pretrain_dataright_e300_bs8_ms_img864_', total_batch_size=8)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
#pre-train MW weights without multi-scale 
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 300 --img 864 864 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights '' --name pretrain_dataright_e300_bs8_img864_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='pretrain_dataright_e300_bs8_img864_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/pretrain_dataright_e300_bs8_img864_', total_batch_size=8)
# tensorboard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# ...

# %%
#transfer learn Lincolnbeet on COCO weights for 300 epochs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 300 --img 864 864 --multi-scale --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights yolov7.pt --name transferlearn_linb_e300_bs8_ms_img864_coco_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_linb_e300_bs8_ms_img864_coco_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_linb_e300_bs8_ms_img864_coco_3', total_batch_size=8)
# ...

# %%
#transfer learn Lincolnbeet on COCO weights for 300 epochs without ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 300 --img 864 864 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights yolov7.pt --name transferlearn_linb_e300_bs8_img864_coco_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_linb_e300_bs8_img864_coco_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_linb_e300_bs8_img864_coco_', total_batch_size=8)
# ...

# %%
#transfer learn Lincolnbeet on best weights MW dataset for 300 epcohs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 300 --img 864 864 --multi-scale --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt --name transferlearn_linb_e300_bs8_ms_img864_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_linb_e300_bs8_ms_img864_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_linb_e300_bs8_ms_img864_', total_batch_size=8)
# ...

# %%
#transfer learn Lincolnbeet on best weights MW dataset for 300 epochs without ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 300 --img 864 864 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights runs/train/pretrain_dataright_e300_bs8_img864_/weights/best.pt --name transferlearn_linb_e300_bs8_img864_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='runs/train/pretrain_dataright_e300_bs8_img864_/weights/best.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_linb_e300_bs8_img864_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_linb_e300_bs8_img864_', total_batch_size=8)
# ...

# %%
#transfer learn Lincolnbeet on COCO weights for 25 epochs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 25 --img 864 864 --multi-scale --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights yolov7.pt --name transferlearn_linb_e25_bs8_ms_img864_coco_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=25, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_linb_e25_bs8_ms_img864_coco_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_linb_e25_bs8_ms_img864_coco_', total_batch_size=8)
# ...

# %%
#transfer learn Lincolnbeet on best weights MW for 25 epochs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 25 --img 864 864 --multi-scale --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt --name transferlearn_linb_e25_bs8_ms_img864_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=25, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_linb_e25_bs8_ms_img864_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_linb_e25_bs8_ms_img864_', total_batch_size=8)
# ...

# %%
#transfer learn Lincolnbeet on COCO weights for 15 epochs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 15 --img 864 864 --multi-scale --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights yolov7.pt --name transferlearn_linb_e15_bs8_ms_img864_coco_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=15, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_linb_e15_bs8_ms_img864_coco_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_linb_e15_bs8_ms_img864_coco_', total_batch_size=8)
# ...

# %%
#transfer learn Lincolnbeet on best weights MW for 15 epochs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 15 --img 864 864 --multi-scale --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt --name transferlearn_linb_e15_bs8_ms_img864_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=15, batch_size=8, img_size=[864, 864], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_linb_e15_bs8_ms_img864_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_linb_e15_bs8_ms_img864_', total_batch_size=8)
# ...

# %%
#transfer learn Grapes on best weights MW for 300 epochs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --multi-scale --epochs 300 --img 512 512 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt --name transferlearn_grapes_e300_bs8_ms_img512_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[512, 512], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_grapes_e300_bs8_ms_img512_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_grapes_e300_bs8_ms_img512_', total_batch_size=8)
# ...

# %%
#transfer learn Grapes on COCO weights for 300 epochs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --multi-scale --epochs 300 --img 512 512 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights yolov7.pt --name transferlearn_grapes_e300_bs8_ms_img512_coco_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[512, 512], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_grapes_e300_bs8_ms_img512_coco_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_grapes_e300_bs8_ms_img512_coco_', total_batch_size=8)
# ...

# %%
#transfer learn Grapes on best weights MW for 300 epochs without ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 300 --img 512 512 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt --name transferlearn_grapes_e300_bs8_img512_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[512, 512], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_grapes_e300_bs8_img512_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_grapes_e300_bs8_img512_3', total_batch_size=8)
# ...

# %%
#transfer learn Grapes on COCO weights for 300 epochs without ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 300 --img 512 512 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights yolov7.pt --name transferlearn_grapes_e300_bs8_img512_coco_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=300, batch_size=8, img_size=[512, 512], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_grapes_e300_bs8_img512_coco_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_grapes_e300_bs8_img512_coco_', total_batch_size=8)
# ...

# %%
#transfer learn Grapes on best weights MW for 20 epochs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --multi-scale --epochs 20 --img 512 512 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt --name transferlearn_grapes_e20_bs8_ms_img512_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=20, batch_size=8, img_size=[512, 512], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_grapes_e20_bs8_ms_img512_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_grapes_e20_bs8_ms_img512_', total_batch_size=8)
# ...

# %%
#transfer learn Grapes on best weights MW for 20 epochs with ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --multi-scale --epochs 20 --img 512 512 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights yolov7.pt --name transferlearn_grapes_e20_bs8_ms_img512_coco_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='yolov7.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=20, batch_size=8, img_size=[512, 512], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=True, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_grapes_e20_bs8_ms_img512_coco_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_grapes_e20_bs8_ms_img512_coco_', total_batch_size=8)
# ...

# %%
#transfer learn Grapes on best weights MW for 10 epochs without ms
# %cd /home/jovyan/yolov7
# !python train.py --device 0 --batch-size 8 --epochs 10 --img 512 512 --data data/custom_data.yaml --hyp data/hyp.scratch.custom.yaml --cfg cfg/training/yolov7-custom.yaml --weights runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt --name transferlearn_grapes_e10_bs8_img512_
# Out:
# /home/jovyan/yolov7
# YOLOR 🚀 v0.1-122-g3b41c2c torch 1.12.0+cu116 CUDA:0 (NVIDIA TITAN RTX, 24212.375MB)
#
# Namespace(weights='runs/train/pretrain_dataright_e300_bs8_ms_img864_/weights/best.pt', cfg='cfg/training/yolov7-custom.yaml', data='data/custom_data.yaml', hyp='data/hyp.scratch.custom.yaml', epochs=10, batch_size=8, img_size=[512, 512], rect=False, resume=False, nosave=False, notest=False, noautoanchor=False, evolve=False, bucket='', cache_images=False, image_weights=False, device='0', multi_scale=False, single_cls=False, adam=False, sync_bn=False, local_rank=-1, workers=8, project='runs/train', entity=None, name='transferlearn_grapes_e10_bs8_img512_', exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias='latest', freeze=[0], v5_metric=False, world_size=1, global_rank=-1, save_dir='runs/train/transferlearn_grapes_e10_bs8_img512_', total_batch_size=8)
# ...
